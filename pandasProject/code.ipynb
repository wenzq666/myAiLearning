# %% [markdown]
# # Pandas
#  - DataFrames

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
score_df = pd.DataFrame(np.random.randint(40,101,(4,3)))
print(type(score_df))
score_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     0   1   2
# 0  46  81  49
# 1  51  74  43
# 2  41  66  47
# 3  40  80  78

# %%
score_df.describe()
# Out:
#                0          1         2
# count   4.000000   4.000000   4.00000
# mean   44.500000  75.250000  54.25000
# std     5.066228   6.898067  16.02862
# min    40.000000  66.000000  43.00000
# 25%    40.750000  72.000000  46.00000
# 50%    43.500000  77.000000  48.00000
# 75%    47.250000  80.250000  56.25000
# max    51.000000  81.000000  78.00000

# %%
#python字典创建 df对象
my_dicts = {
  "name": ['迪丽热巴', '古力娜扎', '鸡你太美'],
  "sex": [0, 0, 1],
  "desc": ['run', 'walk', ['sing','jump','rap']]
}

df_dict = pd.DataFrame(my_dicts)
print(type(df_dict))
df_dict
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    name  sex               desc
# 0  迪丽热巴    0                run
# 1  古力娜扎    0               walk
# 2  鸡你太美    1  [sing, jump, rap]

# %%
df_dict.to_dict()
# Out:
# {'name': {0: '迪丽热巴', 1: '古力娜扎', 2: '鸡你太美'},
#  'sex': {0: 0, 1: 0, 2: 1},
#  'desc': {0: 'run', 1: 'walk', 2: ['sing', 'jump', 'rap']}}

# %% [markdown]
# ###### 访问索引

# %%
df_dict.columns
# Out:
# Index(['name', 'sex', 'desc'], dtype='object')

# %%
df_dict.columns.tolist()
# Out:
# ['name', 'sex', 'desc']

# %%
df_dict.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df_dict.index.tolist()
# Out:
# [0, 1, 2]

# %% [markdown]
# ###### 重新设置索引

# %%
df_dict.index=['A','B','C']

# %%
df_dict.columns=['name','sex','desc']

# %% [markdown]
# ###### 选取列数据

# %%
print(type(df_dict['name']))
df_dict['name']
# Out:
# <class 'pandas.core.series.Series'>
# A    迪丽热巴
# B    古力娜扎
# C    鸡你太美
# Name: name, dtype: object

# %% [markdown]
# ###### 选取行数据

# %%
df_dict
# Out:
#    name  sex               desc
# A  迪丽热巴    0                run
# B  古力娜扎    0               walk
# C  鸡你太美    1  [sing, jump, rap]

# %%
df_dict.loc['C']
# Out:
# name                 鸡你太美
# sex                     1
# desc    [sing, jump, rap]
# Name: C, dtype: object

# %%
df_dict.loc['B':]
# Out:
#    name  sex               desc
# B  古力娜扎    0               walk
# C  鸡你太美    1  [sing, jump, rap]

# %%
df_dict.iloc[0:1,0:2]
# Out:
#    name  sex
# A  迪丽热巴    0

# %% [markdown]
# #### 数据处理

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
print(len(titanic))
print(titanic.shape)
# Out:
# 891
# (891, 12)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.dtypes  # 每一列类型
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(titanic['Sex'].unique())
# 等级
print(titanic['Pclass'].unique())
# 存活属性
print(titanic['Survived'].unique())
# Out:
# ['male' 'female']
# [3 1 2]
# [0 1]

# %%
# groupby  分类统计
titanic[['Sex','PassengerId']].groupby(['Sex']).count()
# Out:
#         PassengerId
# Sex
# female          314
# male            577

# %%
survive_by_class = titanic[['Pclass', 'Survived', 'PassengerId']].groupby(['Pclass', 'Survived']).count()

# %%
survive_by_class = survive_by_class.reset_index()
survive_by_class = survive_by_class.rename(columns={"PassengerId": "count"})
survive_by_class
# Out:
#    Pclass  Survived  count
# 0       1         0     80
# 1       1         1    136
# 2       2         0     97
# 3       2         1     87
# 4       3         0    372
# 5       3         1    119

# %%
import seaborn as sns
plt.figure(facecolor='white')
sns.barplot(data=survive_by_class,
            x="Pclass",
            y="count", hue="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ###### time

# %%
time = pd.to_datetime("2026-08-25")
time
# Out:
# Timestamp('2026-08-25 00:00:00')

# %%
time = pd.to_datetime("2026-08-25 14:25:23")

print(time.year)
print(time.month)
print(time.day)
print(time.hour)
print(time.minute)
print(time.second)
# Out:
# 2026
# 8
# 25
# 14
# 25
# 23
